# %%
import pandas as pd
import numpy as np

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### Q.1)Read superstore data

# %%
supst=pd.read_excel(r"D:\\VS code\\datasets\\Superstore.xls")
supst.head()
# Out:
#     no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0  NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ##### Q.2)find the index of the data

# %%
supst.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# ##### Q.3)find the columns of the data

# %%
supst.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ##### Q.4). if columns name is having space then remove the space and rename the column. find the various ways to rename the column

# %%
supst.columns.str.replace(" ","")
# Out:
# Index(['no', 'order_id', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'Sub-Category', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ##### Q.5)display first 40 records

# %%
supst.head(40)
# Out:
#       no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# ##### Q.6). display last 15 records from the data

# %%
supst.tail(15)
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# ##### Q.7)change the setting to display minimum 30 rows for given data

# %%
pd.options.display.min_rows=30

# %%
supst
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7        8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8        9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 9       10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10      11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11      12.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 12      13.0  CA-2017-114412 2017-04-15 2017-04-20  Standard Class
# ...

# %% [markdown]
# ##### Q.8)change the display setting to minimum row as 3

# %%
pd.options.display.min_rows=3

# %%
supst
# Out:
#           no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...      ...             ...        ...        ...           ...         ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States    Henderson  ...       42420
# ...            ...       ...            ...          ...  ...         ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# ...

# %% [markdown]
# ##### Q.9)take a slice from the dataframe based on the columns city, state, region, profit columns

# %%
supst.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
pd.options.display.min_rows=5

# %%
supst.loc[:,["City","State","Region","Profit"]]
# Out:
#              City       State Region    Profit
# 0       Henderson    Kentucky  South   41.9136
# 1       Henderson    Kentucky  South  219.5820
# ...           ...         ...    ...       ...
# 9992   Costa Mesa  California   West   13.3200
# 9993  Westminster  California   West   72.9480
#
# [9994 rows x 4 columns]

# %% [markdown]
# ##### Q.10)Take a slice based on data available at 1000 to 1500 position and columns from 4 to 8

# %%
supst.index=range(1900,1900+len(supst))

# %%
supst
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# ...       ...             ...        ...        ...             ...
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       Customer ID Customer Name   Segment        Country         City  ...  \
# 1900     CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# 1901     CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...           ...           ...       ...            ...          ...  ...
# 11892    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 11893    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#       Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ##### Q.12)Take a slice from data based on index having name as 1920 , 1940, 1945, 1980, and columns as profit, state, category, sub-category, region

# %%
supst.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
supst.loc[[1920,1940,1945,1980],["Profit","State","Category","Sub-Category","Region"]]
# Out:
#        Profit       State         Category Sub-Category   Region
# 1920   7.3840  California  Office Supplies      Binders     West
# 1940  41.7564       Texas       Technology       Phones  Central
# 1945   8.2062   Minnesota  Office Supplies      Binders  Central
# 1980   8.0352     Alabama  Office Supplies      Binders    South

# %% [markdown]
# ##### Q.13)Check the data type of columns

# %%
type(supst.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ##### Q.14)Find out the record for the month of jun-2014

# %%
supst.dtypes
# Out:
# no                      float64
# order _id                object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
supst[(supst['Order Date']>='2014-06-01') & (supst['Order Date']<='2014-06-30') ]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11745  9846.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       Customer ID      Customer Name   Segment        Country         City  \
# 1905     BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# 1906     BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# ...           ...                ...       ...            ...          ...
# 11745    RE-19450   Richard Eichhorn  Consumer  United States      Decatur
# 11796    JF-15415  Jennifer Ferguson  Consumer  United States      Chicago
#
#        ... Postal Code   Region       Product ID         Category  \
# ...

# %% [markdown]
# ##### Q.15)Calculate month wise average of profit.

# %%
supst['Month']=supst['Order Date'].dt.month
monthly_prof=supst.groupby('Month')['Profit'].mean()
print(monthly_prof)
# Out:
# Month
# 1     23.974924
# 2     34.315369
# 3     41.084321
# 4     17.346462
# 5     30.491575
# 6     29.687302
# 7     19.482626
# 8     30.845522
# 9     26.650380
# 10    38.808353
# 11    24.111779
# 12    30.801983
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Q.16)Create the new data frame for California

# %%
supst["State"].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
supst[supst["State"]=="California"]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       Customer ID    Customer Name    Segment        Country         City  \
# 1902     DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles
# 1905     BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles
# ...           ...              ...        ...            ...          ...
# 11892    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa
# 11893    CC-12220     Chris Cortes   Consumer  United States  Westminster
#
#        ... Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ##### Q.17)Find sum of sales

# %%
supst["Sales"].sum()
# Out:
# np.float64(2297200.8603000003)

# %% [markdown]
# ##### Q.18)Find state wise sum of sales.

# %%
obj=supst.groupby("State")
obj.Sales.sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %% [markdown]
# ##### Q.19)Find month wise sum of sales

# %%
supst.groupby('Month')["Sales"].sum()
# Out:
# Month
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %% [markdown]
# ##### Q.20)Find country wise and city wise average profit

# %%
supst.groupby(["Country","City"])["Profit"].mean()
# Out:
# Country        City
# United States  Aberdeen      6.630000
#                Abilene      -3.758400
#                               ...
#                Yucaipa      13.208000
#                Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %% [markdown]
# ##### Q.21)Calculate region wise average profit.

# %%
supst.groupby("Region")["Profit"].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Q.22)Find the ship mode which is more profitable.

# %%
supst.groupby("Ship Mode")["Profit"].sum().idxmax()
# Out:
# 'Standard Class'

# %% [markdown]
# ##### Q.23)Create a new data frame where loss is recorded

# %%
supst[supst["Profit"]<0]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1914     15.0  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# ...       ...             ...        ...        ...             ...
# 11837  9938.0  CA-2016-164889 2016-06-03 2016-06-06    Second Class
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       Customer ID     Customer Name      Segment        Country  \
# 1903     SO-20335    Sean O'Donnell     Consumer  United States
# 1914     HP-14815     Harold Pawlan  Home Office  United States
# ...           ...               ...          ...            ...
# 11837    CP-12340    Christine Phan    Corporate  United States
# 11862    CM-12655  Corinna Mitchell  Home Office  United States
#
#                   City  ...   Region       Product ID         Category  \
# 1903   Fort Lauderdale  ...    South  FUR-TA-10000577        Furniture
# ...

# %% [markdown]
# ##### Q.24)Find category wise sub category wise sales

# %%
pd.DataFrame(supst.groupby(["Category","Sub-Category"])["Sales"].sum())
# Out:
#                                     Sales
# Category        Sub-Category
# Furniture       Bookcases     114879.9963
#                 Chairs        328449.1030
#                 Furnishings    91705.1640
#                 Tables        206965.5320
# Office Supplies Appliances    107532.1610
#                 Art            27118.7920
#                 Binders       203412.7330
#                 Envelopes      16476.4020
#                 Fasteners       3024.2800
#                 Labels         12486.3120
#                 Paper          78479.2060
#                 Storage       223843.6080
#                 Supplies       46673.5380
# Technology      Accessories   167380.3180
#                 Copiers       149528.0300
#                 Machines      189238.6310
#                 Phones        330007.0540

# %% [markdown]
# ##### Q.25)Create a data frame for record where discount is 0

# %%
pd.options.display.min_rows=10

# %%
supst[supst["Discount"]==0]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11887  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11888  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       Customer ID    Customer Name    Segment        Country         City  \
# 1900     CG-12520      Claire Gute   Consumer  United States    Henderson
# ...

# %%
supst["Discount"]
# Out:
# 1900     0.00
# 1901     0.00
# 1902     0.00
# 1903     0.45
# 1904     0.20
#          ...
# 11889    0.20
# 11890    0.00
# 11891    0.20
# 11892    0.00
# 11893    0.00
# Name: Discount, Length: 9994, dtype: float64

# %% [markdown]
# ##### Q.26)Create a data frame where order date and ship date both are in JAN-2014

# %%
supst[((supst["Order Date"]>="2014-06-01") & (supst["Order Date"]<="2014-06-30")) & ((supst["Ship Date"]>="2014-06-01") & (supst["Ship Date"]<="2014-06-30"))]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1909     10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11664  9765.0  CA-2014-123855 2014-06-18 2014-06-23  Standard Class
# 11743  9844.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11744  9845.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11745  9846.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       Customer ID      Customer Name   Segment        Country         City  \
# ...

# %% [markdown]
# ##### Q.27)Find records having profit for consumer segment.

# %%
supst.groupby(["Segment"])["Profit"].sum()
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Q.28)Generate new data frame for every state (hint: dynamic variable creation)

# %%
state_groups = supst.groupby('State')

for state,group in state_groups:
    var_name=state.replace(" ","_").replace("-","_")
    exec(f"{var_name} = group")
California_df=pd.DataFrame(California)
California_df
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11886  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11892  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#       Customer ID    Customer Name    Segment        Country         City  \
# 1902     DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles
# ...

# %% [markdown]
# ##### Q.29)Generate the region wise, state wise average profit and sales and then extract information for east region.

# %%
avg_pro = supst.groupby(["Region","State"]).agg({'Profit':'mean','Sales':'mean'})

a=pd.DataFrame(avg_pro)
a.loc['East']
# Out:
#                           Profit       Sales
# State
# Connecticut            42.823071  163.223866
# Delaware              103.930988  285.948635
# District of Columbia  105.958930  286.502000
# Maine                  56.810775  158.816250
# Maryland               66.963608  225.766886
# Massachusetts          50.262975  212.106919
# New Hampshire          63.203807  270.093481
# New Jersey             75.176260  275.110092
# New York               65.637011  275.599531
# Ohio                  -36.186304  166.861697
# Pennsylvania          -26.507598  198.487077
# Rhode Island          130.100523  404.070643
# Vermont               204.088936  811.760909
# West Virginia          46.480400  302.456000

# %% [markdown]
# ##### Q.30)Find all record for furniture delivered in Texas

# %%
supst[(supst["Category"]=="Furniture") & (supst["State"]=="Texas")]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1936     37.0  CA-2016-117590 2016-12-08 2016-12-10     First Class
# 1938     39.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 1939     40.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 1976     77.0  US-2017-118038 2017-12-09 2017-12-11     First Class
# 1978     79.0  US-2014-147606 2014-11-26 2014-12-01    Second Class
# ...       ...             ...        ...        ...             ...
# 11731  9832.0  CA-2014-113257 2014-12-16 2014-12-18    Second Class
# 11734  9835.0  CA-2016-126627 2016-10-10 2016-10-12     First Class
# 11803  9904.0  CA-2014-122609 2014-11-12 2014-11-18  Standard Class
# 11819  9920.0  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       Customer ID     Customer Name      Segment        Country        City  \
# ...
